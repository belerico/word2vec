# %% [markdown]
# <a href="https://colab.research.google.com/github/belerico/word2vec/blob/master/word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/belerico/word2vec.git
# Out:
# Cloning into 'word2vec'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 67 (delta 28), reused 60 (delta 21), pack-reused 0
# Unpacking objects: 100% (67/67), done.

# %%
# !wget "http://mattmahoney.net/dc/text8.zip"
# Out:
# --2020-08-12 15:45:54--  http://mattmahoney.net/dc/text8.zip
# Resolving mattmahoney.net (mattmahoney.net)... 67.195.197.24
# Connecting to mattmahoney.net (mattmahoney.net)|67.195.197.24|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31344016 (30M) [application/zip]
# Saving to: ‘text8.zip’
#
# text8.zip           100%[===================>]  29.89M   745KB/s    in 42s
#
# 2020-08-12 15:46:36 (730 KB/s) - ‘text8.zip’ saved [31344016/31344016]

# %%
# !unzip text8.zip
# !mv text8 word2vec/word2vec/data/dataset
# %cd word2vec
# Out:
# Archive:  text8.zip
#   inflating: text8
# /content/word2vec

# %%
# !ls -al
# Out:
# total 28
# drwxr-xr-x 4 root root 4096 Aug 12 15:44 .
# drwxr-xr-x 1 root root 4096 Aug 12 15:50 ..
# drwxr-xr-x 8 root root 4096 Aug 12 15:44 .git
# -rw-r--r-- 1 root root 2034 Aug 12 15:44 .gitignore
# -rw-r--r-- 1 root root 1448 Aug 12 15:44 main.py
# -rw-r--r-- 1 root root  255 Aug 12 15:44 README.md
# drwxr-xr-x 3 root root 4096 Aug 12 15:44 word2vec

# %%
# !python main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Progress: 49.5999%, Elapsed: 210.92s, Lr: 0.00050406, Loss: 65486.9227
# Progress: 49.8007%, Elapsed: 211.55s, Lr: 0.0005022, Loss: 5959.0075
# Progress: 50.0015%, Elapsed: 212.15s, Lr: 0.00050014, Loss: 10955.3683
# Progress: 50.6039%, Elapsed: 215.01s, Lr: 0.00049407, Loss: 9153.5507
# Progress: 50.8047%, Elapsed: 215.61s, Lr: 0.00049195, Loss: 86031.3353
# Progress: 51.2064%, Elapsed: 217.90s, Lr: 0.000488, Loss: 22410.2132
# Progress: 51.4072%, Elapsed: 218.51s, Lr: 0.00048595, Loss: 142530.5149
# Progress: 51.6080%, Elapsed: 219.09s, Lr: 0.00048402, Loss: 9379.4073
# Progress: 51.8088%, Elapsed: 219.67s, Lr: 0.00048193, Loss: 48687.4302
# Progress: 52.0096%, Elapsed: 221.36s, Lr: 0.00048014, Loss: 6877.8708
# Progress: 52.2104%, Elapsed: 221.98s, Lr: 0.00047808, Loss: 10287.5571
# Progress: 52.4112%, Elapsed: 222.59s, Lr: 0.00047593, Loss: 35124.3443
# Progress: 52.8128%, Elapsed: 224.86s, Lr: 0.00047199, Loss: 12123.5599
# ...
